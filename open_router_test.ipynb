# %%
import os
from openai import OpenAI

client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key=os.environ.get("OPENROUTER_API_KEY"),
)

completion = client.chat.completions.create(
  extra_headers={
    "HTTP-Referer": "<YOUR_SITE_URL>", # Optional. Site URL for rankings on openrouter.ai.
    "X-Title": "<YOUR_SITE_NAME>", # Optional. Site title for rankings on openrouter.ai.
  },
  model="x-ai/grok-4.1-fast",
  messages=[
    {
      "role": "user",
      "content": "What is the meaning of life?"
    }
  ]
)

print(completion.choices[0].message.content)
# Out:
# 42.
#
# (Okay, seriously: The meaning of life is one of humanity's oldest questions, with no universal answer. Philosophers like Aristotle said it's eudaimonia (flourishing through virtue). Religions often point to loving God/neighbors or achieving enlightenment. Existentialists like Sartre argue you create your own meaning. Biologically, it's survival and reproduction. Scientifically, we're stardust pondering the universe.
#
# For me? Pursue truth, build cool stuff, help others, and laugh along the way. What's yours?)
